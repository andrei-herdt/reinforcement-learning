# %%
import warnings; warnings.simplefilter('ignore')

# %%
fig=plt.figure(figsize=(12,7), dpi= 80, facecolor='w', edgecolor='k')
# %run plot.py data/sb_rtg_na_CartPole-v0_03-12-2017_09-18-24 data/sb_rtg_dna_CartPole-v0_01-12-2017_22-07-48 data/sb_no_rtg_dna_CartPole-v0_05-11-2017_10-48-40

# %%
plot.py
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a8193935e0b1> in <module>()
# ----> 1 plot.py
#
# NameError: name 'plot' is not defined
